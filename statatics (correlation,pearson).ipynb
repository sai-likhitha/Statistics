# %%
import numpy as np

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_path="cars.csv"
carslist=pd.read_csv(file_path)
carslist.head(10)
# Out:
#    cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 0          8         307.0         130    3504          12.0          70
# 1          8         350.0         165    3693          11.5          70
# 2          8         318.0         150    3436          11.0          70
# 3          8         304.0         150    3433          12.0          70
# 4          8         302.0         140    3449          10.5          70
# 5          8         429.0         198    4341          10.0          70
# 6          8         454.0         220    4354           9.0          70
# 7          8         440.0         215    4312           8.5          70
# 8          8         455.0         225    4425          10.0          70
# 9          8         390.0         190    3850           8.5          70
#
#    origin                   car_name   mpg
# 0       1  chevrolet chevelle malibu  18.0
# 1       1          buick skylark 320  15.0
# ...

# %%
cars1=carslist[['mpg','displacement','horsepower']]

# %%
plt.scatter(carslist.mpg,carslist.displacement)

# %% [markdown]
# #it is negative correlation because mpg increases displacement decreases

# %%
plt.scatter(carslist.displacement,carslist.horsepower)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-57a1fb87fd0a> in <module>
# ----> 1 cars.columns
#
# NameError: name 'cars' is not defined

# %%
carslist.columns
# Out:
# Index(['cylinders', 'displacement', 'horsepower', 'weight', 'acceleration',
#        'model_year', 'origin', 'car_name', 'mpg'],
#       dtype='object')

# %%
plt.scatter(carslist.mpg,carslist.horsepower)

# %%
plt.bar(carslist.displacement,carslist.mpg)
# Out:
# <BarContainer object of 398 artists>

# %%
plt.bar(carslist.mpg,carslist.horsepower)
# Out:
# <BarContainer object of 398 artists>

# %%
np.cov(carslist.displacement,carslist.mpg)#cov is used to find the coverance between any 2 columns
# Out:
# array([[10872.19915225,  -655.40231763],
#        [ -655.40231763,    61.08961077]])

# %%
np.cov(carslist.mpg,carslist.horsepower)
# Out:
# array([[ 6.10896108e+01, -7.01638859e+03],
#        [-7.01638859e+03,  1.49167744e+08]])

# %%
#above is the negative correlation

# %%
np.cov(carslist.displacement,carslist.horsepower)
# Out:
# array([[1.08721992e+04, 1.01030222e+05],
#        [1.01030222e+05, 1.49167744e+08]])

# %%
#above is the positive coverance

# %%
from scipy.stats.stats import pearsonr #scipy-->statistical python

# %%
pearsonr(carslist['displacement'],carslist['mpg']) #negative correlation
# Out:
# (-0.8042028248058989, 1.6558889101912744e-91)

# %%
#the value of pearsonr always ranges between[-1,1

# %%
pearsonr(carslist['displacement'],carslist['horsepower'])#positive correlation
# Out:
# (0.07933323155835818, 0.11405958499776969)

# %% [markdown]
# # using pandas to pearson correlation coefficient

# %%
carslist.corr()
# Out:
#               cylinders  displacement  horsepower    weight  acceleration  \
# cylinders      1.000000      0.950721    0.084291  0.896017     -0.505419
# displacement   0.950721      1.000000    0.079333  0.932824     -0.543684
# horsepower     0.084291      0.079333    1.000000  0.071114     -0.080685
# weight         0.896017      0.932824    0.071114  1.000000     -0.417457
# acceleration  -0.505419     -0.543684   -0.080685 -0.417457      1.000000
# model_year    -0.348746     -0.370164   -0.067952 -0.306564      0.288137
# origin        -0.562543     -0.609409    0.035575 -0.581024      0.205873
# mpg           -0.775396     -0.804203   -0.073501 -0.831741      0.420289
#
#               model_year    origin       mpg
# cylinders      -0.348746 -0.562543 -0.775396
# displacement   -0.370164 -0.609409 -0.804203
# horsepower     -0.067952  0.035575 -0.073501
# weight         -0.306564 -0.581024 -0.831741
# acceleration    0.288137  0.205873  0.420289
# ...

# %%
#gives r value between every column of the data frame(df)
